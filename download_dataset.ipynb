# %%
import praw
import numpy as np
import requests
from PIL import Image
from io import BytesIO
import os

# %%
reddit = praw.Reddit(
client_id="RhHg9UYRJVGnc1wbqabryQ",
client_secret="pcyFCvdeVPzDz6aWqxXqycjMsuEOgQ",
password="sohamvadikaustubh",
user_agent="safepost-classifier by u/nusteprojects",
username="nusteprojects",
)

# %%
#Downloding sfw dataset

subreddit = reddit.subreddit("pics")
# Fetch the top 10 SFW image posts from the subreddit
count = 0
for idx, submission in enumerate(subreddit.new(limit=300)):
    if not submission.over_18 and submission.url.endswith(('jpg', 'jpeg', 'png')):
        try:
            response = requests.get(submission.url)
            if response.status_code == 200:
                img = Image.open(BytesIO(response.content))
                # Save the image with its original filename in the 'pics_images' directory
                img = img.convert("RGB")
                img.save(os.path.join("data\sfw_images", f"image_{idx}.jpg"))
                count +=1
        except : 
                continue
print(count)
# Out:
# C:\Users\Kaustubh Virkar\anaconda3\lib\site-packages\PIL\Image.py:3074: DecompressionBombWarning: Image size (108601500 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 249

# %%
#downloading NSFW data set
# gore
subreddit = reddit.subreddit("MedicalGore")
# Fetch the top 10 SFW image posts from the subreddit
if not os.path.exists("nsfw_images"):
    os.makedirs("nsfw_images")
count = 0
for idx, submission in enumerate(subreddit.top(limit=200)):
    if submission.over_18 and submission.url.endswith(('jpg', 'jpeg', 'png')):
        try:
            response = requests.get(submission.url)
            if response.status_code == 200:
                img = Image.open(BytesIO(response.content))
                # Save the image with its original filename in the 'pics_images' directory
                img = img.convert("RGB")
                print("here")
                img.save(os.path.join("nsfw_images", f"image_{idx}.jpg"))
                count +=1
        except Exception as e :
            print("error : " , e)
            continue
print(count)
# Out:
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# 161

# %%
#downloading NSFW data set
# guns
subreddit = reddit.subreddit("guns")
# Fetch the top 10 SFW image posts from the subreddit
if not os.path.exists("nsfw_images"):
    os.makedirs("nsfw_images")
count = 0
for idx, submission in enumerate(subreddit.top(limit=200)):
    if submission.over_18 and submission.url.endswith(('jpg', 'jpeg', 'png')):
        try:
            response = requests.get(submission.url)
            if response.status_code == 200:
                img = Image.open(BytesIO(response.content))
                # Save the image with its original filename in the 'pics_images' directory
                img = img.convert("RGB")
                print("here")
                img.save(os.path.join("nsfw_images", f"image_{idx}.jpg"))
                count +=1
        except Exception as e :
            print("error : " , e)
            continue
print(count)
# Out:
# 0
